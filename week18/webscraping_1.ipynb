# %% [markdown]
# # Webpages
#
# Webpages are built mainly with 3 tools:
#
#     HTML: content (structure, headings, paragraphs, tables...)
#     CSS: style (color, shape, size...)
#     JavaScript: logic (clicks, popups, dynamic banners...)

# %% [markdown]
# ## HTML
# Basics
#
# HTML code consists of `<tagged>` content.
#
# HTML has a hierarchichal structure: parent tags, children tags, sibling tags:
# ```
# <html>
#     <head>
#         <title>Page Title</title>
#     </head>
#     <body>
#         <h1>My First Heading</h1>
#         <p>My first paragraph.</p>
#     </body>
# </html>
# ```

# %% [markdown]
# ### Tags
#
# Tags may be classified in different groups, depending on the type of content they are expected to posess
# ```
# heading: <h1>, <h2>, <h3>, <hgroup>...
# phrasing: <b>, <img>, <sub>...
# embedded: <audio>, <img>, <video>, <href>...
# tabulated: <table>, <tr>, <tbody>...
# sections: <header>, <section>, <article>, <div>...
# metadata: <meta>, <title>, <script>...
# ```

# %% [markdown]
# ### Attributes
#
# This tag has no attributes `<div> Zapas Marca Joma X54 </div>`
#
# Tags may have attributes. Here, the div tag has:
#
#     a class attribute with value price-item
#     an id attribute with value offer
# ```
# <div class="price-item" id="offer"> Zapas Marca Joma X54 </div>
# ```
# id attribute should be ***unique*** for a tag (no two tags should have same id)
#
# class is not intended to be unique, it usually groups tags with similar behavior
#
# Other frequently used tags are:
# ```
#     dir
#     lang
#     style (not to be confused with <style> tag)
#     title (not to be confused with <title> tag)
# ```

# %% [markdown]
# ### Web scraping
# Intro
#
# When scraping, we want to filter tags by:
# ```
#     tag name
#     class
#     id
#     other attribute
# ```
#
# Our browser Console is very useful for this: we can Inspect content in the web and find the corresponding piece of HTML code
#
# We use requests library to bring the HTML content to our Python script
#
# We use `Beautiful Soup` library to easily navigate through the HTML in Python

# %%
# Descargamos la librería bs4
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\mrusso\miniconda3\envs\data_science_py395\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mrusso\miniconda3\envs\data_science_py395\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
# Otras librerías para poder interactuar con una web
import requests
from bs4 import BeautifulSoup

# %%
# Probamos a navegar en una web
url = "https://www.elpais.com"

# Lanzamos la request
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# Comprobamos el contenido
response.content
# Out:
# b'<!DOCTYPE html><html lang="es-ES"><head><link rel="preconnect" href="//static.elpais.com"/><link rel="preconnect" href="//ep00.epimg.net"/><link rel="preconnect" href="//imagenes.elpais.com"/><link rel="preload" as="script" href="//ep00.epimg.net/js/prisa/user.min.js?i=1"/><link rel="preconnect" href="//www.googletagservices.com"/><link rel="preconnect" href="//ping.chartbeat.net"/><link rel="preconnect" href="//cdn.krxd.net"/><link rel="preconnect" href="//assets.adobedtm.com"/><link rel="preload" href="https://static.elpais.com/dist/resources/fonts/majrit/majrit-text/Majrit-Text-Bold.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://static.elpais.com/dist/resources/fonts/majrit/majrit-text/Majrit-Text-Roman.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://static.elpais.com/dist/resources/fonts/marcin-ant-b/marcinantb-regular-webfont.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://static.elpais.com/dist/resources/fonts/majrit/majrit-text/Majrit-Text-Bold-Italic.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://static.elpais.com/dist/resources/fonts/majrit/majrit-text/Majrit-Text-Black.woff2" as="font" type="font/woff2" crossorigin=""/><link rel="preload" href="https://static.elpais.com/dist/resources/fonts/marcin-ant-b/marcinantb-bold-webfont.woff2" as="font" type="font/woff2" crossorigin=""/><script type="application/javascript">window.ENP = {"globalContent":{"website":"el-pais","alertEnabled":true,"subscribeLinkByIP":"https://elpais.com/suscripciones/america/#/campaign#?","subscribeLink":"https://elpais.com/suscripciones/#/campaign#?","favoritesURL":"https://static.elpais.com/dist/resources/js/4e495fb1/ENP-favorites.js"},"deployment":{"arcVersion":"1191","cssVersion":"4e495fb1","jsVersion":"4e495fb1","resourcePath":"https://static.elpais.com/dist"},"translations":{"dateTime":{"dateTimeConnector":"a las","ago":"Hace %s"},"sharedBar":{"copyLink":"Enlace copiado"}},"envVars":{"firebaseTokenURL":"https://5fzdat48x6.execute-api.eu-west-1.amazonaws.com/INT/getauth","firebaseConfig":{"apiKey":"AIzaSyAJQ7zoB6Nsnx5kE6yTTnVvLO-ZbmKqBfM","authDomain":"elpais-desarrollo.firebaseapp.com","projectId":"elpais-desarrollo","appId":"1:557747584702:web:a7f93d44104f0358b568ef"}},"siteProperties":{"liveKickerUrl":"https://eskup.elpais.com/OuteskupSimple","languageCode":"es-ES","siteDomainURL":"https://elpais.com"},"disabledFeatures":{"NOFAV":true,"NOPUBLI":false,"NOCSS":false},"overrideCss":null};</script><script type="application/javascript">window.LANG = "es-ES";</script><script type="text/javascript" id="enp-script-0" src="https://static.elpais.com/dist/resources/js/4e495fb1/ENP-section-front.js" defer=""></script><script src="https://contributor.google.com/scripts/1d9eb4aae2cdce07/loader.js" defer=""></script><script type="text/javascript">\n          var EP=EP||{};\n          (function(e){e.FC={getCookie:function(a){a+="=";for(var d=document.cookie.split(";"),b=0;b<d.length;b++){for(var c=d[b];" "==c.charAt(0);)c=c.substring(1,c.length);if(0==c.indexOf(a))return c.substring(a.length,c.length)}return null},getReleasedStorage:function(a,d){my_storage=window.localStorage;var b=my_storage.getItem(a);if(null!==b&&-1!=b.indexOf("|")){var c=b.substring(0,b.indexOf("|"));b=b.substring(b.indexOf("|")+1,b.length);if(c==\n          d||"mostrarFC"==a&&"SI"==b)return b}return null},setReleasedStorage:function(a,d,b){my_storage=window.localStorage;my_storage.setItem(a,d+"|"+b)},cumpleAleatorio:function(a){return cumple_aleatorio=100*Math.random()<a?!0:!1},init:function(){es_suscriptor=!1;var a=EP.FC.getCookie("uid_ns");es_suscriptor=null==a?!1:null==a.match(/144\\|([0-9]+)/)?!1:!0;window.googlefc=window.googlefc||{};googlefc.controlledMessagingFunction=function(a){(es_suscriptor||true)?a.proceed(!1):a.proceed(!0)}}};EP.FC.init()})(EP);\n          (function(){\'use strict\';var f=function(a){var b=0;return funct ...

# %%
# Check del type
type(response.content)
# Out:
# bytes

# %% [markdown]
# > Tal como ocurre para el fichero `json` es un formato serializado, necesitaremos deserializarlo.
# >

# %%
# Utilizamos soup para este labor de deserialización
soup = BeautifulSoup(response.content)
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# > si lanzamos esta consulta dentro del inspector del navegador obtenemos los resultados linkables en color rojo
#
# ```
# document.querySelectorAll('a').forEach(elm => elm.style.background = 'red')
# ```

# %%
# Enviamos una petición similar con bs4 y recogemos los anchor text ('a')
posibles_elementos_a = soup.select("a")
len(posibles_elementos_a)
# Out:
# 583

# %%
# Enviamos una petición similar con bs4 y recogemos los h2 de estos anchor text
posibles_elementos_h2 = soup.select("h2 a")
len(posibles_elementos_h2)
# Out:
# 143

# %%
# Enviamos una petición similar con bs4 y recogemos los h2
posibles_elementos_h1 = soup.select("h1")
len(posibles_elementos_h1)
# Out:
# 1

# %%
type(posibles_elementos_h1) # el formato output es una list
# Out:
# bs4.element.ResultSet

# %%
# Para extraer el contenido textual recorremos elementos del listado y seleccionaremos text
posibles_elementos_h2[0].text
# Out:
# 'El PP se conjura para enterrar la etapa de Casado en torno a Feijóo'

# %%
# Sacamos todos los textos del formato h2 y lo guardamos en una nueva lista
lista_h2 = [h2.text for h2 in posibles_elementos_h2]
len(lista_h2)
# Out:
# 143

# %%
lista_h2[:5]
# Out:
# ['El PP se conjura para enterrar la etapa de Casado en torno a Feijóo',
#  'Gamarra: “Putin es un problema pero la causa de nuestra crisis es Sánchez”',
#  'Aznar: “Pablo, donde quiera que esté, gracias”',
#  'Ayuso: “Este congreso es la respuesta a una crisis que nunca debió existir”',
#  'Videoanálisis | ¿Es el fin de la crisis del Partido Popular?']

# %% [markdown]
# ### Realizamos una extracción de los resultados de búsqueda en Google

# %%
# El primer paso para realizar scraping es crear un agente del navegador
USER_AGENT = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

# %% [markdown]
# > Queremos extraer los resultados de unos términos de búsqueda

# %%
# Creamos una lista de
kwterms = ['python', 'data science','data analytics', 'big data']

# %%
# Creamos la funciones de recogida de los resultados
def fetch_results(search_term, num_results, lang_code, country_code, time_results):
    assert isinstance(search_term, str), 'Search term tiene que ser una string'
    assert isinstance(num_results, int), 'Número de resultado tiene que ser entero'
    escaped_search_term = search_term.replace(' ', '+')

    google_url = 'https://www.google.es/search?q={}&num={}&hl={}&cr=country{}&as_qdr={}'.format(escaped_search_term, 
                                                                                                 num_results,
                                                                                                 lang_code,
                                                                                                 country_code,
                                                                                                 time_results)
    response = requests.get(google_url, headers=USER_AGENT)
    response.raise_for_status()

    return search_term, response.text

# %% [markdown]
# > Definimos una función para extraer de la página de resultados de Google los elementos solicitados

# %%
# Parse Results for Google Search
def parse_results(html, keyword):
    soup = BeautifulSoup(html, 'html.parser')

    found_results = []
    rank = 1
    result_block = soup.find_all('div', attrs={'class': 'g'})
    for result in result_block:

        link = result.find('a', href=True)
        title = result.find('h3')
        description = result.find('span', attrs={'class': 'MUxGbd wuQ4Ob WZ8Tjf'})
        if link and title:
            link = link['href']
            title = title.get_text()
            if description:
                description = description.get_text()
            if link != '#':
                found_results.append({'keyword': keyword, 'rank': rank, 'title': title, 
                                      'description': description, 'link':link})
                rank += 1
    return found_results

# %%
# Guardamos la información
import pandas as pd

def store_data(keyword, rank, title, description, link):
    google_se = pd.DataFrame({
        "keyword":keyword,
        "rank":rank,
        "title":title,
        "description":description,
        "link":link   
    })
    return google_se

# %%
# Recoger la información y almacenar en una base de datos

def on_data(data):
    #This is the meat of the script...it connects to your mongoDB and stores the search results
    try:
        # Create dataJson
        for i in data:
                   
        #grab the keys and values
            keyword = i['keyword']
            rank = i['rank']
            title = i['title']
            description = i['description']
            link = i['link']
           
            #insert the data into the MySQL database
            store_data(keyword, rank, title, description, link)

    except Exception as e:
        print(e)

# %%
# Scraping Web function for Google SEARCH only 50 results, spanish, Spain, last 1 day
def scrape_web(search_term):
        keyword, html = fetch_results(search_term, 50, "es", "ES" ,"d") # last 1 day
        results = parse_results(html, keyword)
        return results

# %%
# # Scraping Web function for Google SEARCH only 1000 results, spanish, Spain, all results
# def scrape_web(search_term):
#         keyword, html = fetch_results(search_term, 1000, "es", "ES" ,"all") # all results
#         results = parse_results(html, keyword)
#         return results

# %%
# Testing googleScraping
data = []
results = scrape_web(kwterms[0])
#results = scrape_web('master data science')
for result in results:
    data.append(result)

# %%
len(results)
# Out:
# 46

# %%
results
# Out:
# [{'keyword': 'python',
#   'rank': 1,
#   'title': 'Trabajo de Python en Barcelona - InfoJobs',
#   'description': 'hace 10 horas — ',
#   'link': 'https://www.infojobs.net/ofertas-trabajo/barcelona/python'},
#  {'keyword': 'python',
#   'rank': 2,
#   'title': 'CT02 - PYTHON Developer (Inglés Alto) - LinkedIn',
#   'description': 'hace 14 horas — ',
#   'link': 'https://es.linkedin.com/jobs/view/ct02-python-developer-ingl%C3%A9s-alto-at-ingefor-2999666368'},
#  {'keyword': 'python',
#   'rank': 3,
#   'title': '4.1. Acércate a Python | Cambiamos el mundo - Junta de ...',
#   'description': None,
#   'link': 'https://edea.juntadeandalucia.es/bancorecursos/file/653ee80d-2517-4e6b-938d-8fc23331967f/1/PRO_2BAC_REA_01_V01.zip/41_acrcate_a_python.html'},
#  {'keyword': 'python',
#   'rank': 4,
#   'title': '4.1. Acércate a Python | Cambiamos el mundo - Junta de ...',
#   'description': None,
#   'link': 'https://edea.juntadeandalucia.es/bancorecursos/file/653ee80d-2517-4e6b-938d-8fc23331967f/1/PRO_2BAC_REA_01_V01.zip/41_acrcate_a_python.html'},
#  {'keyword': 'python',
#   'rank': 5,
#   'title': '4.2. "Hola Python" | Cambiamos el mundo - Junta de Andalucia',
#   'description': None,
#   'link': 'https://edea.juntadeandalucia.es/bancorecursos/file/653ee80d-2517-4e6b-938d-8fc23331967f/1/PRO_2BAC_REA_01_V01.zip/42_hola_python.html'},
#  {'keyword': 'python',
#   'rank': 6,
#   'title': 'Introducción a los dispositivos gemelos (Python) - Microsoft ...',
#   'description': 'hace 18 horas — ',
#   'link': 'https://docs.microsoft.com/es-es/azure/iot-hub/iot-hub-python-twin-getstarted'},
#  {'keyword': 'python',
#   'rank': 7,
#   'title': 'Building a Hash Table in Python and Thoughtful REST API ...',
#   'description': 'hace 20 horas — ',
#   'link': 'https://www.ivoox.com/building-a-hash-table-in-python-and-thoughtful-audios-mp3_rf_85016372_1.html'},
#  {'keyword': 'python',
#   'rank': 8,
#   'title': 'Clases de inteligencia artificial en python - Wallapop',
#   'description': 'hace 15 horas — ',
#   'link': 'https://es.wallapop.com/item/clases-de-inteligencia-artificial-en-python-771061790'},
#  {'keyword': 'python',
#   'rank': 9,
#   'title': 'DATA Engineer / Data Governance - Tecnoempleo',
#   'description': 'hace 23 horas — ',
#   'link': 'https://www.tecnoempleo.com/data-engineer-data-governance-madrid/sql-etl-python-r-powerbi/rf-3f24rbb08za57q41e4m1'},
#  {'keyword': 'python',
#   'rank': 10,
#   'title': 'Empezar con Anaconda Python - Byte Spider',
#   'description': 'hace 7 horas — ',
#   'link': 'https://bytespider.eu/empezar-con-anaconda-python/'},
#  {'keyword': 'python',
#   'rank': 11,
#   'title': 'Ingeniero/a Software en Esplugues De Llobregat España',
#   'description': 'hace 20 horas — ',
#   'link': 'https://www.adecco.es/oferta-trabajo/ingenieroa-software?ID=62b696e6-ce1b-4c98-a2ce-d469c1395380'},
#  {'keyword': 'python',
#   'rank': 12,
#   'title': 'Noticias de Tecnología, Gaming, Ciencia, Ocio e Industria',
#   'description': 'hace 21 horas — ',
#   'link': 'https://computerhoy.com/noticias?brands=0&form_build_id=form-MTtgFSr-hyJkcYvo57CNlk4Ej9YBbk_9Bk8ESo_1lOQ&form_id=external_card_selector&products=0&type=tablet&page=2081'},
#  {'keyword': 'python',
#   'rank': 13,
#   'title': 'Papelería Meganova en Vilagarcía desde 1994',
#   'description': 'hace 11 horas — ',
#   'link': 'https://www.meganova.es/es/libro/python-practico-herramientas-conceptos-y-tecnicas_5770190015'},
#  {'keyword': 'python',
#   'rank': 14,
#   'title': 'Eventos - Polo de Contenidos Digitales',
#   'description': 'hace 11 horas — ',
#   'link': 'https://www.polodigital.eu/eventos/'},
#  {'keyword': 'python',
#   'rank': 15,
#   'title': 'Converse x Golf Wang Chuck 70 OX Python Blue - Jofemar',
#   'description': 'hace 23 horas — ',
#   'link': 'https://www.jofemar.com/en/fdcejlshop/pt/p/converse-x-golf-wang-chuck-70-ox-python-blue-173190c'},
#  {'keyword': 'python',
#   'rank': 16,
#   'title': 'flutter eta dart - www.lanbide.euskadi.eus',
#   'description': 'hace 21 horas — ',
#   'link': 'https://apps.lanbide.euskadi.net/apps/CE_DETALLE_ESPECIALIDAD?LG=E&ML=FORMEN1&MS=O&IDCE=IFCD35&ORGN='},
#  {'keyword': 'python',
#   'rank': 17,
#   'title': 'Achetez Converse CHUCK 70 OX - 173189C - Sivasdescalzo',
#   'description': 'hace 4 horas — ',
#   'link': 'https://www.sivasdescalzo.com/fr/p/chuck-70-ox-173189c'},
#  {'keyword': 'python',
#   'rank': 18,
#   'title': 'Python: agregar elemento a la lista N veces - Foro Ayuda',
#   'description': 'hace 6 horas — ',
#   'link': 'https://foroayuda.es/python-agregar-elemento-a-la-lista-n-veces/'},
#  {'keyword': 'python',
#   'rank': 19,
#   'title': 'Events - CRG',
#   'description': 'hace 5 horas — ',
#   'link': 'https://www.crg.eu/en/events'},
#  {'keyword': 'python',
#   'rank': 20,
#   'title': 'Todo Real - Nunca dejes de aprender',
#   'description': 'hace 12 horas — ',
#   'link': 'https://todoreal.com/'},
#  {'keyword': 'python',
#   'rank': 21,
#   'title': 'Monthly Picks – CASETiFY (ES)',
#   'description': 'hace 8 horas — ',
#   'link': 'https://www.casetify.com/es_ES/collections/Monthly-Picks'},
#  {'keyword': 'python',
#   'rank': 22,
#   'title': 'Codelearn Sant Cugat | Escola de programació, robòtica i ...',
#   'description': 'hace 10 horas — ',
#   'link': 'https://codelearn.cat/sant-cugat/'},
#  {'keyword': 'python',
#   'rank': 23,
#   'title': 'RIA platinum nappa Color platino Sizes 36 - Farrutx',
#   'description': 'hace 16 horas — ',
#   'link': 'https://farrutx.com/en/sandals/2733-ria-platinum-nappa-.html'},
#  {'keyword': 'python',
#   'rank': 24,
#   'title': 'Noticias de Ocio y cultura - Cadena SER',
#   'description': 'hace 24 horas — ',
#   'link': 'https://cadenaser.com/ocio-y-cultura,,,monty-python-a,terry-gilliam-a,obituario-a,cine-a/'},
#  {'keyword': 'python',
#   'rank': 25,
#   'title': 'AZURE EXPERT, sáb, 2 abr 2022, 7:00 | Meetup',
#   'description': 'hace 13 horas — ',
#   'link': 'https://www.meetup.com/es-ES/london-software-training-virajetech-com-the-best-e-learning/events/rdmftsydcgbdb/'},
#  {'keyword': 'python',
#   'rank': 26,
#   'title': 'EsGeeks » Seguridad & Informática & Hacking',
#   'description': 'hace 12 horas — ',
#   'link': 'https://esgeeks.com/'},
#  {'keyword': 'python',
#   'rank': 27,
#   'title': 'Banco de datos | Real Academia Española',
#   'description': 'hace 13 horas — ',
#   'link': 'https://www.rae.es/banco-de-datos'},
#  {'keyword': 'python',
#   'rank': 28,
#   'title': 'Cursos GRATIS de Adobe,Power BI,Excel, Java, PHP, C++ ...',
#   'description': 'hace 19 horas — ',
#   'link': 'https://www.chollometro.com/ofertas/cursos-gratis-de-adobepower-biexcel-java-php-c-javascript-seo-react-js-html-certificaciones-examenes-wordpress-y-otros-udemy-769205'},
#  {'keyword': 'python',
#   'rank': 29,
#   'title': 'Software de entorno de desarrollo integrado Python ...',
#   'description': 'hace 6 horas — ',
#   'link': 'http://vistamister.net/software-de-entorno-de-desarrollo-integrado-python-prevision-de-nuevos-desarrollos-2022-2030/'},
#  {'keyword': 'python',
#   'rank': 30,
#   'title': 'Encuentra proyectos online | twago',
#   'description': 'hace 14 horas — ',
#   'link': 'https://www.twago.es/s/projects/'},
#  {'keyword': 'python',
#   'rank': 31,
#   'title': 'Valencianistes de calbot, por Josep Bosch - Plaza Deportiva',
#   'description': 'hace 7 horas — ',
#   'link': 'https://plazadeportiva.valenciaplaza.com/valencianistes-de-calbot'},
#  {'keyword': 'python',
#   'rank': 32,
#   'title': 'Noticias - Facultad de Ciencias de la Universidad de Granada',
#   'description': 'hace 10 horas — ',
#   'link': 'https://fciencias.ugr.es/en/34-noticias'},
#  {'keyword': 'python',
#   'rank': 33,
#   'title': 'Coincidentally similar submissions in Codeforces Round #779',
#   'description': 'hace 14 horas — ',
#   'link': 'https://codeforces.com/blog/entry/101337'},
#  {'keyword': 'python',
#   'rank': 34,
#   'title': 'Pràctiques en Empresa per a Informàtics a la Xarxa - ETSInf',
#   'description': 'hace 21 horas — ',
#   'link': 'https://intranet.inf.upv.es/int/aplic_intranet/peixboot/alumnos/listado_ofertas_5_detalle.php'},
#  {'keyword': 'python',
#   'rank': 35,
#   'title': 'Antivirus Libre ClamWin. Software de codigo abierto de ...',
#   'description': 'hace 23 horas — ',
#   'link': 'http://es.clamwin.com/content/view/18/46/'},
#  {'keyword': 'python',
#   'rank': 36,
#   'title': 'BSG Institute - Conocimiento para Crecer - Centros de ...',
#   'description': 'hace 14 horas — ',
#   'link': 'https://cursos.elpais.com/centros/bsg-institute-conocimiento-para-crecer-1151963-centrodetalles.htm'},
#  {'keyword': 'python',
#   'rank': 37,
#   'title': 'Cotización de NIKE -B-: Acciones e información - Bolsamania',
#   'description': 'hace 14 horas — ',
#   'link': 'https://www.bolsamania.com/accion/NIKE--B-'},
#  {'keyword': 'python',
#   'rank': 38,
#   'title': 'John Cleese - SEMANA',
#   'description': 'hace 23 horas — ',
#   'link': 'https://www.semana.es/famosos/famoso/john-cleese/'},
#  {'keyword': 'python',
#   'rank': 39,
#   'title': '2.076 Ofertas de trabajo de React - 1 de abril, 2022 - Indeed',
#   'description': 'hace 22 horas — ',
#   'link': 'https://es.indeed.com/Ofertas-de-React'},
#  {'keyword': 'python',
#   'rank': 40,
#   'title': 'Bilbao BBK Live Festival 2022 - La Ganzua',
#   'description': 'hace 23 horas — ',
#   'link': 'https://www.laganzua.net/festivales/bilbao-bbk-live-festival-2022-bilbao-974334'},
#  {'keyword': 'python',
#   'rank': 41,
#   'title': 'Academia Oposiciones y Cursos Santander - MasterD',
#   'description': 'hace 13 horas — ',
#   'link': 'https://www.masterd.es/delegaciones/santander/1800'},
#  {'keyword': 'python',
#   'rank': 42,
#   'title': 'Se Busca Profe De Estadística (Leer) - Tus clases particulares',
#   'description': 'hace 21 horas — ',
#   'link': 'https://www.tusclasesparticulares.com/alumnos/online/estadistica/busca-profe-estadistica-leer-online-3116950'},
#  {'keyword': 'python',
#   'rank': 43,
#   'title': 'Instituto de la Cultura y las Artes de Sevilla',
#   'description': 'hace 19 horas — ',
#   'link': 'https://icas.sevilla.org/'},
#  {'keyword': 'python',
#   'rank': 44,
#   'title': 'Eventos de 美年体检报告多久可以查询快速定制 - Eventbrite',
#   'description': 'hace 12 horas — ',
#   'link': 'https://www.eventbrite.es/d/online/%E7%BE%8E%E5%B9%B4%E4%BD%93%E6%A3%80%E6%8A%A5%E5%91%8A%E5%A4%9A%E4%B9%85%E5%8F%AF%E4%BB%A5%E6%9F%A5%E8%AF%A2%E5%BF%AB%E9%80%9F%E5%AE%9A%E5%88%B6%EF%BC%8C%E6%8E%92%E7%89%88-ps%EF%BC%88-%E8%96%87:a586103)/'},
#  {'keyword': 'python',
#   'rank': 45,
#   'title': 'Programa formativo do Centro de Novas Tecnoloxías de ...',
#   'description': None,
#   'link': 'https://www.coruna.gal/informacionjuvenil/es/convocatorias/cursos/detalle-cursos/programa-formativo-do-centro-de-novas-tecnoloxias-de-galicia-2021-2022/suceso/1453779170156?argIdioma=es'},
#  {'keyword': 'python',
#   'rank': 46,
#   'title': 'Trabajos de Remoto en Manilva (10 Empleos) | Jobted.es',
#   'description': 'hace 3 horas — ',
#   'link': 'https://www.jobted.es/trabajo-remoto-en-manilva'}]

# %%
dataset = pd.DataFrame(results)
dataset
# Out:
#    keyword  rank                                              title  \
# 0   python     1          Trabajo de Python en Barcelona - InfoJobs
# 1   python     2   CT02 - PYTHON Developer (Inglés Alto) - LinkedIn
# 2   python     3  4.1. Acércate a Python | Cambiamos el mundo - ...
# 3   python     4  4.1. Acércate a Python | Cambiamos el mundo - ...
# 4   python     5  4.2. "Hola Python" | Cambiamos el mundo - Junt...
# 5   python     6  Introducción a los dispositivos gemelos (Pytho...
# 6   python     7  Building a Hash Table in Python and Thoughtful...
# 7   python     8  Clases de inteligencia artificial en python - ...
# 8   python     9      DATA Engineer / Data Governance - Tecnoempleo
# 9   python    10          Empezar con Anaconda Python - Byte Spider
# 10  python    11  Ingeniero/a Software en Esplugues De Llobregat...
# 11  python    12  Noticias de Tecnología, Gaming, Ciencia, Ocio ...
# 12  python    13        Papelería Meganova en Vilagarcía desde 1994
# 13  python    14             Eventos - Polo de Contenidos Digitales
# 14  python    15  Converse x Golf Wang Chuck 70 OX Python Blue -...
# 15  python    16         flutter eta dart - www.lanbide.euskadi.eus
# 16  python    17  Achetez Converse CHUCK 70 OX - 173189C - Sivas...
# 17  python    18  Python: agregar elemento a la lista N veces - ...
# 18  python    19                                       Events - CRG
# 19  python    20                Todo Real - Nunca dejes de aprender
# 20  python    21                      Monthly Picks – CASETiFY (ES)
# 21  python    22  Codelearn Sant Cugat | Escola de programació, ...
# 22  python    23  RIA platinum nappa Color platino Sizes 36 - Fa...
# 23  python    24            Noticias de Ocio y cultura - Cadena SER
# 24  python    25       AZURE EXPERT, sáb, 2 abr 2022, 7:00 | Meetup
# 25  python    26        EsGeeks » Seguridad & Informática & Hacking
# 26  python    27            Banco de datos | Real Academia Española
# 27  python    28  Cursos GRATIS de Adobe,Power BI,Excel, Java, P...
# 28  python    29  Software de entorno de desarrollo integrado Py...
# 29  python    30                 Encuentra proyectos online | twago
# 30  python    31  Valencianistes de calbot, por Josep Bosch - Pl...
# 31  python    32  Noticias - Facultad de Ciencias de la Universi...
# 32  python    33  Coincidentally similar submissions in Codeforc...
# 33  python    34  Pràctiques en Empresa per a Informàtics a la X...
# 34  python    35  Antivirus Libre ClamWin. Software de codigo ab...
# 35  python    36  BSG Institute - Conocimiento para Crecer - Cen...
# 36  python    37  Cotización de NIKE -B-: Acciones e información...
# 37  python    38                               John Cleese - SEMANA
# 38  python    39  2.076 Ofertas de trabajo de React - 1 de abril...
# 39  python    40          Bilbao BBK Live Festival 2022 - La Ganzua
# 40  python    41  Academia Oposiciones y Cursos Santander - MasterD
# 41  python    42  Se Busca Profe De Estadística (Leer) - Tus cla...
# 42  python    43     Instituto de la Cultura y las Artes de Sevilla
# 43  python    44           Eventos de 美年体检报告多久可以查询快速定制 - Eventbrite
# 44  python    45  Programa formativo do Centro de Novas Tecnolox...
# 45  python    46  Trabajos de Remoto en Manilva (10 Empleos) | J...
#
#          description                                               link
# 0   hace 10 horas —   https://www.infojobs.net/ofertas-trabajo/barce...
# 1   hace 14 horas —   https://es.linkedin.com/jobs/view/ct02-python-...
# 2               None  https://edea.juntadeandalucia.es/bancorecursos...
# 3               None  https://edea.juntadeandalucia.es/bancorecursos...
# 4               None  https://edea.juntadeandalucia.es/bancorecursos...
# 5   hace 18 horas —   https://docs.microsoft.com/es-es/azure/iot-hub...
# 6   hace 20 horas —   https://www.ivoox.com/building-a-hash-table-in...
# 7   hace 15 horas —   https://es.wallapop.com/item/clases-de-intelig...
# 8   hace 23 horas —   https://www.tecnoempleo.com/data-engineer-data...
# 9    hace 7 horas —   https://bytespider.eu/empezar-con-anaconda-pyt...
# 10  hace 20 horas —   https://www.adecco.es/oferta-trabajo/ingeniero...
# 11  hace 21 horas —   https://computerhoy.com/noticias?brands=0&form...
# 12  hace 11 horas —   https://www.meganova.es/es/libro/python-practi...
# 13  hace 11 horas —                 https://www.polodigital.eu/eventos/
# 14  hace 23 horas —   https://www.jofemar.com/en/fdcejlshop/pt/p/con...
# 15  hace 21 horas —   https://apps.lanbide.euskadi.net/apps/CE_DETAL...
# 16   hace 4 horas —   https://www.sivasdescalzo.com/fr/p/chuck-70-ox...
# 17   hace 6 horas —   https://foroayuda.es/python-agregar-elemento-a...
# 18   hace 5 horas —                        https://www.crg.eu/en/events
# 19  hace 12 horas —                               https://todoreal.com/
# 20   hace 8 horas —   https://www.casetify.com/es_ES/collections/Mon...
# 21  hace 10 horas —                   https://codelearn.cat/sant-cugat/
# 22  hace 16 horas —   https://farrutx.com/en/sandals/2733-ria-platin...
# 23  hace 24 horas —   https://cadenaser.com/ocio-y-cultura,,,monty-p...
# 24  hace 13 horas —   https://www.meetup.com/es-ES/london-software-t...
# 25  hace 12 horas —                                https://esgeeks.com/
# 26  hace 13 horas —                   https://www.rae.es/banco-de-datos
# 27  hace 19 horas —   https://www.chollometro.com/ofertas/cursos-gra...
# 28   hace 6 horas —   http://vistamister.net/software-de-entorno-de-...
# 29  hace 14 horas —                    https://www.twago.es/s/projects/
# 30   hace 7 horas —   https://plazadeportiva.valenciaplaza.com/valen...
# 31  hace 10 horas —             https://fciencias.ugr.es/en/34-noticias
# 32  hace 14 horas —            https://codeforces.com/blog/entry/101337
# 33  hace 21 horas —   https://intranet.inf.upv.es/int/aplic_intranet...
# 34  hace 23 horas —           http://es.clamwin.com/content/view/18/46/
# 35  hace 14 horas —   https://cursos.elpais.com/centros/bsg-institut...
# 36  hace 14 horas —          https://www.bolsamania.com/accion/NIKE--B-
# 37  hace 23 horas —   https://www.semana.es/famosos/famoso/john-cleese/
# 38  hace 22 horas —              https://es.indeed.com/Ofertas-de-React
# 39  hace 23 horas —   https://www.laganzua.net/festivales/bilbao-bbk...
# 40  hace 13 horas —   https://www.masterd.es/delegaciones/santander/...
# 41  hace 21 horas —   https://www.tusclasesparticulares.com/alumnos/...
# 42  hace 19 horas —                           https://icas.sevilla.org/
# 43  hace 12 horas —   https://www.eventbrite.es/d/online/%E7%BE%8E%E...
# 44              None  https://www.coruna.gal/informacionjuvenil/es/c...
# 45   hace 3 horas —     https://www.jobted.es/trabajo-remoto-en-manilva

# %%
import time

if __name__ == '__main__':
    
    data = []
    for keyword in kwterms:
        try:
            results = scrape_web(keyword)
            
            for result in results:
                data.append(result)
             
        except Exception as e:
            print(e)
        finally:
            time.sleep(60)
    #print(data)
    # Call function to store data
    on_data(data)

# %% [markdown]
# > Otro Ejemplo desde una página de wikipedia

# %%
# Ejemplo extraemos las informaciones de wikipedia
# Cargamos las librerías requests y pandas

import requests
import pandas as pd

# %%
url = "https://es.wikipedia.org/wiki/Anexo:Municipios_de_la_Comunidad_de_Madrid"

# Lanzamos la requests
respuesta = requests.get(url)
respuesta.status_code
# Out:
# 200

# %%
# Comprobamos el contenido
respuesta.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Anexo:Municipios de la Comunidad de Madrid - Wikipedia, la enciclopedia libre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xc2\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"12ea14c4-fdd8-4221-b541-4c1f8cff9edf","wgCSPNonce":false,"wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Municipios_de_la_Comunidad_de_Madrid","wgTitle":"Municipios de la Comunidad de Madrid","wgCurRevisionId":141671874,"wgRevisionId":141671874,"wgArticleId":22109,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Anexos:Municipios de Espa\xc3\xb1a","Municipios de Espa\xc3\xb1a por comunidad aut\xc3\xb3noma","Municipios de Espa\xc3\xb1a por provincia","Municipios de la Comunidad de Madrid","Anexos:Comunidad de Madrid"],"wgPageContentLanguage":"es",\n"wgPageContentModel":"wikitext","wgRelevantPageName":"Anexo:Municipios_de_la_Comunidad_de_Madrid","wgRelevantArticleId":22109,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":50000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"espa\xc3\xb1ol","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q93237","wgGENewcomerTasksGuidanceEnabled":true,"wgGEAskQuestionEnabled":false,"wgGELinkRecommendationsFrontendEnabled":true};RLSTATE={"ext.gadget.imagenesinfobox":"ready",\n"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","skins.vector.legacy.js","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface"]\n;</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1i9g4",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=es&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=s ...

# %%
# Guardamos el contenido
codigoHTML = respuesta.text
codigoHTML
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Anexo:Municipios de la Comunidad de Madrid - Wikipedia, la enciclopedia libre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"12ea14c4-fdd8-4221-b541-4c1f8cff9edf","wgCSPNonce":false,"wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Municipios_de_la_Comunidad_de_Madrid","wgTitle":"Municipios de la Comunidad de Madrid","wgCurRevisionId":141671874,"wgRevisionId":141671874,"wgArticleId":22109,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Anexos:Municipios de España","Municipios de España por comunidad autónoma","Municipios de España por provincia","Municipios de la Comunidad de Madrid","Anexos:Comunidad de Madrid"],"wgPageContentLanguage":"es",\n"wgPageContentModel":"wikitext","wgRelevantPageName":"Anexo:Municipios_de_la_Comunidad_de_Madrid","wgRelevantArticleId":22109,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":50000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"español","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q93237","wgGENewcomerTasksGuidanceEnabled":true,"wgGEAskQuestionEnabled":false,"wgGELinkRecommendationsFrontendEnabled":true};RLSTATE={"ext.gadget.imagenesinfobox":"ready",\n"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","skins.vector.legacy.js","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface"]\n;</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1i9g4",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=es&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=styles&amp;skin=vector"/>\n<link rel="sty ...

# %%
#!pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-4.8.0-cp39-cp39-win_amd64.whl (3.6 MB)
# Installing collected packages: lxml
# Successfully installed lxml-4.8.0

# %%
# En pandas tenemos la función pd.read_html que nos permitirá leer este código
dataframe = pd.read_html(codigoHTML, header=0)
dataframe
# Out:
# [                    Nombre Población(2021)  Superficie (km²)[1]​  Mapa  \
#  0               La Acebeda              55                  2206   NaN
#  1                  Ajalvir            4676                  1962   NaN
#  2        Alameda del Valle             246                  2501   NaN
#  3                 El Álamo            9908                  2225   NaN
#  4        Alcalá de Henares          195982                  8772   NaN
#  ..                     ...             ...                   ...   ...
#  174        Villar del Olmo            1997                  2762   NaN
#  175  Villarejo de Salvanés            7245                 11862   NaN
#  176   Villaviciosa de Odón          27 504                  6805   NaN
#  177  Villavieja del Lozoya             267                  2329   NaN
#  178              Zarzalejo            1596                  2063   NaN
#
#       Escudo  Altitud(msnm)[a]​[2]​
#  0       NaN                   1271
#  1       NaN                    680
#  2       NaN                   1104
#  3       NaN                    608
#  4       NaN                    587
#  ..      ...                    ...
#  174     NaN                    675
#  175     NaN                    753
#  176     NaN                    661
#  177     NaN                   1060
#  178     NaN                   1104
#
#  [179 rows x 6 columns]]

# %%
# El response es una lista necesitamos extraer el primer elemento para mostrarlo como dataframe
dataframe[0]
# Out:
#                     Nombre Población(2021)  Superficie (km²)[1]​  Mapa  \
# 0               La Acebeda              55                  2206   NaN
# 1                  Ajalvir            4676                  1962   NaN
# 2        Alameda del Valle             246                  2501   NaN
# 3                 El Álamo            9908                  2225   NaN
# 4        Alcalá de Henares          195982                  8772   NaN
# ..                     ...             ...                   ...   ...
# 174        Villar del Olmo            1997                  2762   NaN
# 175  Villarejo de Salvanés            7245                 11862   NaN
# 176   Villaviciosa de Odón          27 504                  6805   NaN
# 177  Villavieja del Lozoya             267                  2329   NaN
# 178              Zarzalejo            1596                  2063   NaN
#
#      Escudo  Altitud(msnm)[a]​[2]​
# 0       NaN                   1271
# 1       NaN                    680
# 2       NaN                   1104
# 3       NaN                    608
# 4       NaN                    587
# ..      ...                    ...
# 174     NaN                    675
# 175     NaN                    753
# 176     NaN                    661
# 177     NaN                   1060
# 178     NaN                   1104
#
# [179 rows x 6 columns]

# %% [markdown]
# > Creamos una lista con la TOP ten de los fugitivos más buscados por la FBI

# %%
import pandas as pd

# %%
# Url del sitio a buscar
url = 'https://www.fbi.gov/wanted/topten'

#your code 
fbi_html = requests.get(url).text
soup_fbi = BeautifulSoup(fbi_html, "html.parser")

buscados = [f.text.strip().replace('\n', '') for f in soup_fbi.find_all('h3', class_= 'title')]
buscados
# Out:
# []

# %% [markdown]
# > Listar las imágenes de Walt Disney

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

#your code
disney_html = requests.get(url).text
soup_disney = BeautifulSoup(disney_html, "html.parser")

enlaces = soup_disney.find_all('img')
images_src = [img['src'].replace('//', '') for img in soup_disney.findAll('img', class_='thumbimage')]
images_src
# Out:
# ['upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  'upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/1/13/DisneySchiphol1951.jpg/220px-DisneySchiphol1951.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/8/8c/WaltDisneyplansDisneylandDec1954.jpg/220px-WaltDisneyplansDisneylandDec1954.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Walt_disney_portrait_right.jpg/170px-Walt_disney_portrait_right.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Walt_Disney_Grave.JPG/170px-Walt_Disney_Grave.JPG',
#  'upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Disney_Oscar_1953_%28cropped%29.jpg/170px-Disney_Oscar_1953_%28cropped%29.jpg',
#  'upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Disney1968.jpg/170px-Disney1968.jpg']

# %%
len(images_src)
# Out:
# 13

# %% [markdown]
# > Buscamos los últimos 20 terremtos por (fecha, hora, lat, lon, region)

# %%
url = 'https://www.emsc-csem.org/Earthquake/'

ea_html = requests.get(url).text
soup_ea = BeautifulSoup(ea_html, "html.parser")

data = []
table = soup_ea.find_all('tr', class_= 'normal')
# Out:
#          date        time   latitude   longitude                        region
# 0  2022-04-02  12:30:46.7  31.68 N    104.44 W                   WESTERN TEXAS
# 1  2022-04-02  12:25:23.5  39.00 S    174.69 E     NORTH ISLAND OF NEW ZEALAND
# 2  2022-04-02  12:24:58.0   6.49 S    129.92 E                       BANDA SEA
# 3  2022-04-02  12:22:29.0   7.47 S    106.88 E                 JAVA, INDONESIA
# 4  2022-04-02  12:21:08.0   9.47 S    117.70 E       SUMBAWA REGION, INDONESIA
