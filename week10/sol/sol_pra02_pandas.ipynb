# %% [markdown]
# # Programación 201

# %% [markdown]
# Librerías científicas en Python: `Pandas`
# ------------------------------------------------------

# %% [markdown]
# ### Ejercicio 1
#
# Cargad los datos del fichero _got.csv_ en un _dataframe_. Este conjunto de datos recoge información de la [Guerra de los Cinco Reyes](https://awoiaf.westeros.org/index.php/War_of_the_Five_Kings) de las novelas de [Cancion de Hielo y Fuego](https://es.wikipedia.org/wiki/Canci%C3%B3n_de_hielo_y_fuego) de George R.R Martin.
#
# Mostrad el número de filas del _dataframe_ y las etiquetas de los ejes.

# %%
# Respuesta
import pandas as pd
df_got = pd.read_csv("https://raw.githubusercontent.com/marcusRB/IDbootcamps_DataScience_student_PT_10201/master/dataset/got.csv")
df_got.head()
# Out:
#                             name  year  ...           region note
# 0     Battle of the Golden Tooth   298  ...  The Westerlands  NaN
# 1    Battle at the Mummer's Ford   298  ...   The Riverlands  NaN
# 2             Battle of Riverrun   298  ...   The Riverlands  NaN
# 3       Battle of the Green Fork   298  ...   The Riverlands  NaN
# 4  Battle of the Whispering Wood   298  ...   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
df_got.sample(10, random_state=17)
# Out:
#                                                  name  ...                                               note
# 28                                Fall of Moat Cailin  ...                                                NaN
# 11                               Battle of Winterfell  ...  It isn't mentioned how many Stark men are left...
# 8                            Battle of Deepwood Motte  ...                                                NaN
# 21                               Battle of Duskendale  ...                                                NaN
# 29                                   Sack of Saltpans  ...                                                NaN
# 37                                Siege of Winterfell  ...                                                NaN
# 18                                 Battle of the Crag  ...                                                NaN
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...  ...                                                NaN
# 34                               Siege of Dragonstone  ...                                                NaN
# 23                            Battle of the Ruby Ford  ...                                                NaN
#
# [10 rows x 25 columns]

# %%
# Comprobar el numero de filas
df_got.shape
# Out:
# (38, 25)

# %%
df_got.shape[0]
# Out:
# 38

# %%
df_got.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
len(df_got)
# Out:
# 38

# %%
df_got.axes
# Out:
# [RangeIndex(start=0, stop=38, step=1),
#  Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#         'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#         'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#         'battle_type', 'major_death', 'major_capture', 'attacker_size',
#         'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#         'location', 'region', 'note'],
#        dtype='object')]

# %% [markdown]
# ### Ejercicio 2
#
# Agrupad los datos cargados en el ejercicio 1 por el principal bando atacante (*attacker\_1*). Para cada posición, mostrad el número de batallas y el resultado de la batalla (el resultado se encuentra en el campo *attacker\_outcome*).

# %%
# Respuesta
df_got2 = df_got.groupby(by='attacker_1')['attacker_outcome'].count()
df_got2
# Out:
# attacker_1
# Baratheon                      5
# Bolton                         2
# Bracken                        1
# Brave Companions               1
# Brotherhood without Banners    1
# Darry                          1
# Free folk                      1
# Frey                           2
# Greyjoy                        7
# Lannister                      8
# Stark                          8
# Name: attacker_outcome, dtype: int64

# %%
type(df_got2)
# Out:
# pandas.core.series.Series

# %%
df_got2.value_counts()
# Out:
# 1    5
# 8    2
# 2    2
# 7    1
# 5    1
# Name: attacker_outcome, dtype: int64

# %%
df_got_grp = df_got.groupby(by='attacker_1', squeeze=True)
df_got_grp['attacker_outcome'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The `squeeze` parameter is deprecated and will be removed in a future version.
#   """Entry point for launching an IPython kernel.
# attacker_1                   attacker_outcome
# Baratheon                    win                 4
#                              loss                1
# Bolton                       win                 2
# Bracken                      win                 1
# Brave Companions             win                 1
# Brotherhood without Banners  win                 1
# Darry                        win                 1
# Free folk                    loss                1
# Frey                         win                 2
# Greyjoy                      win                 7
# Lannister                    win                 7
#                              loss                1
# Stark                        win                 6
#                              loss                2
# Name: attacker_outcome, dtype: int64

# %%
df_got[['attacker_1','attacker_outcome']].sort_values(by='attacker_1')
# Out:
#                      attacker_1 attacker_outcome
# 37                    Baratheon              NaN
# 34                    Baratheon              win
# 33                    Baratheon              win
# 19                    Baratheon             loss
# 30                    Baratheon              win
# 15                    Baratheon              win
# 13                       Bolton              win
# 28                       Bolton              win
# 36                      Bracken              win
# 29             Brave Companions              win
# 22  Brotherhood without Banners              win
# 20                        Darry              win
# 27                    Free folk             loss
# 25                         Frey              win
# 26                         Frey              win
# 11                      Greyjoy              win
# 9                       Greyjoy              win
# 8                       Greyjoy              win
# 7                       Greyjoy              win
# 31                      Greyjoy              win
# 32                      Greyjoy              win
# 12                      Greyjoy              win
# 35                    Lannister              win
# 24                    Lannister              win
# 0                     Lannister              win
# 16                    Lannister             loss
# 6                     Lannister              win
# 2                     Lannister              win
# 1                     Lannister              win
# 23                    Lannister              win
# 21                        Stark             loss
# 17                        Stark              win
# 14                        Stark              win
# 10                        Stark              win
# 5                         Stark              win
# 4                         Stark              win
# 3                         Stark             loss
# 18                        Stark              win

# %%
# Para poder iterar ....
for (attacker, battles) in df_got.groupby(['attacker_1']):
  print(f"El número de batallas que realizaron los {attacker} fueron: {len(battles)}")
# Out:
# El número de batallas que realizaron los Baratheon fueron: 6
# El número de batallas que realizaron los Bolton fueron: 2
# El número de batallas que realizaron los Bracken fueron: 1
# El número de batallas que realizaron los Brave Companions fueron: 1
# El número de batallas que realizaron los Brotherhood without Banners fueron: 1
# El número de batallas que realizaron los Darry fueron: 1
# El número de batallas que realizaron los Free folk fueron: 1
# El número de batallas que realizaron los Frey fueron: 2
# El número de batallas que realizaron los Greyjoy fueron: 7
# El número de batallas que realizaron los Lannister fueron: 8
# El número de batallas que realizaron los Stark fueron: 8

# %%
for (attacker, battles) in df_got.groupby(['attacker_1']):
  print(f"El número de batallas que realizaron los {attacker} fueron {len(battles)} , de las cuales {len(battles[(battles.attacker_outcome == 'win')])} ")
# Out:
# El número de batallas que realizaron los Baratheon fueron 6 , de las cuales 4
# El número de batallas que realizaron los Bolton fueron 2 , de las cuales 2
# El número de batallas que realizaron los Bracken fueron 1 , de las cuales 1
# El número de batallas que realizaron los Brave Companions fueron 1 , de las cuales 1
# El número de batallas que realizaron los Brotherhood without Banners fueron 1 , de las cuales 1
# El número de batallas que realizaron los Darry fueron 1 , de las cuales 1
# El número de batallas que realizaron los Free folk fueron 1 , de las cuales 0
# El número de batallas que realizaron los Frey fueron 2 , de las cuales 2
# El número de batallas que realizaron los Greyjoy fueron 7 , de las cuales 7
# El número de batallas que realizaron los Lannister fueron 8 , de las cuales 7
# El número de batallas que realizaron los Stark fueron 8 , de las cuales 6

# %% [markdown]
# ### Ejercicio 3
#
# Mostrad los datos de las batallas donde el numero de participantes supera los 15000 "hombres" (contando ambos bandos: *attacker\_size* y *defender\_size*), el resultado haya sido favorable para el atacante, y la batalla se haya producido en invierno (_summer=0_).

# %%
# Respuesta
df_got[((df_got['attacker_size'] + df_got['defender_size']) > 15000) & (
    df_got['attacker_outcome'] == 'win') & (
        df_got['summer'] == 0)]
# Out:
# Empty DataFrame
# Columns: [name, year, battle_number, attacker_king, defender_king, attacker_1, attacker_2, attacker_3, attacker_4, defender_1, defender_2, defender_3, defender_4, attacker_outcome, battle_type, major_death, major_capture, attacker_size, defender_size, attacker_commander, defender_commander, summer, location, region, note]
# Index: []

# %% [markdown]
# ### Ejercicio 4
#
# Contad el número de lugares que aparecen más de una vez en _dataframe_ (campo _location_), utilizando las funciones de la librería _pandas_. ¿Existe algún lugar donde se haya realizado más de una batalla? Comprobad qué bandos estaban implicados.

# %%
# Respuesta
duplicated_row = df_got.duplicated(['location'], keep=False)
df_got[duplicated_row]['location']
# Out:
# 2             Riverrun
# 5             Riverrun
# 6                Darry
# 7          Moat Cailin
# 8       Deepwood Motte
# 10    Torrhen's Square
# 11          Winterfell
# 12    Torrhen's Square
# 13          Winterfell
# 15         Storm's End
# 17           Harrenhal
# 20               Darry
# 24           Harrenhal
# 28         Moat Cailin
# 30      Deepwood Motte
# 33         Storm's End
# 35            Riverrun
# 37          Winterfell
# Name: location, dtype: object

# %%
unique_locations = df_got[duplicated_row]['location'].unique()
print(unique_locations)
# Out:
# ['Riverrun' 'Darry' 'Moat Cailin' 'Deepwood Motte' "Torrhen's Square"
#  'Winterfell' "Storm's End" 'Harrenhal']

# %%
sides = ['attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 
         'defender_1','defender_2', 'defender_3', 'defender_4', 'location']
df_got[duplicated_row][sides].sort_values(by = ["location"])
# Out:
#    attacker_1 attacker_2 attacker_3  ... defender_3 defender_4          location
# 6   Lannister        NaN        NaN  ...        NaN        NaN             Darry
# 20      Darry        NaN        NaN  ...        NaN        NaN             Darry
# 8     Greyjoy        NaN        NaN  ...        NaN        NaN    Deepwood Motte
# 30  Baratheon   Karstark    Mormont  ...        NaN        NaN    Deepwood Motte
# 17      Stark        NaN        NaN  ...        NaN        NaN         Harrenhal
# 24  Lannister        NaN        NaN  ...        NaN        NaN         Harrenhal
# 7     Greyjoy        NaN        NaN  ...        NaN        NaN       Moat Cailin
# 28     Bolton        NaN        NaN  ...        NaN        NaN       Moat Cailin
# 2   Lannister        NaN        NaN  ...        NaN        NaN          Riverrun
# 5       Stark      Tully        NaN  ...        NaN        NaN          Riverrun
# 35  Lannister       Frey        NaN  ...        NaN        NaN          Riverrun
# 33  Baratheon        NaN        NaN  ...        NaN        NaN       Storm's End
# 15  Baratheon        NaN        NaN  ...        NaN        NaN       Storm's End
# 10      Stark        NaN        NaN  ...        NaN        NaN  Torrhen's Square
# 12    Greyjoy        NaN        NaN  ...        NaN        NaN  Torrhen's Square
# 13     Bolton    Greyjoy        NaN  ...        NaN        NaN        Winterfell
# 11    Greyjoy        NaN        NaN  ...        NaN        NaN        Winterfell
# 37  Baratheon   Karstark    Mormont  ...        NaN        NaN        Winterfell
#
# [18 rows x 9 columns]

# %%
df_got[duplicated_row][["attacker_1", "defender_1", "location"]].sort_values(by = ["location"])
# Out:
#    attacker_1        defender_1          location
# 6   Lannister             Darry             Darry
# 20      Darry         Lannister             Darry
# 8     Greyjoy             Stark    Deepwood Motte
# 30  Baratheon           Greyjoy    Deepwood Motte
# 17      Stark         Lannister         Harrenhal
# 24  Lannister  Brave Companions         Harrenhal
# 7     Greyjoy             Stark       Moat Cailin
# 28     Bolton           Greyjoy       Moat Cailin
# 2   Lannister             Tully          Riverrun
# 5       Stark         Lannister          Riverrun
# 35  Lannister             Tully          Riverrun
# 33  Baratheon         Baratheon       Storm's End
# 15  Baratheon         Baratheon       Storm's End
# 10      Stark           Greyjoy  Torrhen's Square
# 12    Greyjoy             Stark  Torrhen's Square
# 13     Bolton             Stark        Winterfell
# 11    Greyjoy             Stark        Winterfell
# 37  Baratheon            Bolton        Winterfell

# %% [markdown]
# ### Ejercicio 5
#
# Añadid una nueva columna al _dataframe_ con un valor booleano indicando una predicción básica de si en una cierta batalla el bando atacante será vencedor. Definiremos el valor como _True_ sí el bando atacante es mayor al defensor, y como _False_ en caso contrario. Definid como _NaN_ aquellos casos en los que no haya número de tropas en ningún bando. ¿En que casos, identificados por el número de batalla (*battle\_number*), nuestra predicción coincide con el resultado real?

# %%
# Respuesta Sebastian
import numpy as np
conditions = [
    (df_got['attacker_size'] > df_got['defender_size']),
    (df_got['attacker_size'] < df_got['defender_size'])]
choices = [True, False]
df_got['prediction'] = np.select(conditions, choices, default='NaN')

conditions2 = [
    ((df_got['prediction'] == True) & (df_got['attacker_outcome'] == 'win')),
    ((df_got['prediction'] == True) & (df_got['attacker_outcome'] == 'loss')),
    ((df_got['prediction'] == False) & (df_got['attacker_outcome'] == 'loss')),
    ((df_got['prediction'] == False) & (df_got['attacker_outcome'] == 'win'))]
choices2 = [True, False, True, False]
df_got['succesful_prediction'] = np.select(conditions, choices, default='NaN')

df_got['succesful_prediction'].value_counts()
# Out:
# NaN      24
# False     8
# True      6
# Name: succesful_prediction, dtype: int64

# %%
pd.isna(df_got.attacker_size)
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21    False
# 22     True
# 23     True
# 24     True
# 25    False
# 26     True
# 27    False
# 28     True
# 29     True
# 30    False
# 31     True
# 32     True
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# Name: attacker_size, dtype: bool

# %%
conditions = [
              (df_got.attacker_size > df_got.defender_size),
              (df_got.attacker_size < df_got.defender_size),
              (pd.isna(df_got.attacker_size) & pd.notna(df_got.defender_size)),
              (pd.notna(df_got.attacker_size) & pd.isna(df_got.defender_size))
]

choices = ["True", "False", "False", "True"]
df_got['winner_prediction'] = np.select(conditions, choices, default = "NaN")
df_got
# Out:
#                                                  name  ...  winner_prediction
# 0                          Battle of the Golden Tooth  ...               True
# 1                         Battle at the Mummer's Ford  ...              False
# 2                                  Battle of Riverrun  ...               True
# 3                            Battle of the Green Fork  ...              False
# 4                       Battle of the Whispering Wood  ...              False
# 5                                 Battle of the Camps  ...              False
# 6                                       Sack of Darry  ...                NaN
# 7                               Battle of Moat Cailin  ...                NaN
# 8                            Battle of Deepwood Motte  ...               True
# 9                           Battle of the Stony Shore  ...               True
# 10                         Battle of Torrhen's Square  ...              False
# 11                               Battle of Winterfell  ...               True
# 12                           Sack of Torrhen's Square  ...                NaN
# 13                                 Sack of Winterfell  ...              False
# 14                                  Battle of Oxcross  ...              False
# 15                               Siege of Storm's End  ...              False
# 16                                Battle of the Fords  ...               True
# 17                                  Sack of Harrenhal  ...                NaN
# 18                                 Battle of the Crag  ...               True
# 19                           Battle of the Blackwater  ...               True
# 20                                     Siege of Darry  ...                NaN
# 21                               Battle of Duskendale  ...               True
# 22                       Battle of the Burning Septry  ...                NaN
# 23                            Battle of the Ruby Ford  ...              False
# 24                              Retaking of Harrenhal  ...                NaN
# 25                                    The Red Wedding  ...                NaN
# 26                                   Siege of Seagard  ...                NaN
# 27                             Battle of Castle Black  ...               True
# 28                                Fall of Moat Cailin  ...                NaN
# 29                                   Sack of Saltpans  ...                NaN
# 30                         Retaking of Deepwood Motte  ...               True
# 31                       Battle of the Shield Islands  ...                NaN
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...  ...                NaN
# 33                        Second Seige of Storm's End  ...              False
# 34                               Siege of Dragonstone  ...               True
# 35                                  Siege of Riverrun  ...               True
# 36                                 Siege of Raventree  ...               True
# 37                                Siege of Winterfell  ...              False
#
# [38 rows x 28 columns]

# %%
df_got['prediction'].count()
# Out:
# 38

# %%
# Respuesta Alt.

df_predict = df_got.assign(prediccion=lambda x: x.attacker_size > x.defender_size)
df_predict
# Out:
#                                                  name  ...  prediccion
# 0                          Battle of the Golden Tooth  ...        True
# 1                         Battle at the Mummer's Ford  ...       False
# 2                                  Battle of Riverrun  ...        True
# 3                            Battle of the Green Fork  ...       False
# 4                       Battle of the Whispering Wood  ...       False
# 5                                 Battle of the Camps  ...       False
# 6                                       Sack of Darry  ...       False
# 7                               Battle of Moat Cailin  ...       False
# 8                            Battle of Deepwood Motte  ...       False
# 9                           Battle of the Stony Shore  ...       False
# 10                         Battle of Torrhen's Square  ...       False
# 11                               Battle of Winterfell  ...       False
# 12                           Sack of Torrhen's Square  ...       False
# 13                                 Sack of Winterfell  ...       False
# 14                                  Battle of Oxcross  ...       False
# 15                               Siege of Storm's End  ...       False
# 16                                Battle of the Fords  ...        True
# 17                                  Sack of Harrenhal  ...       False
# 18                                 Battle of the Crag  ...       False
# 19                           Battle of the Blackwater  ...        True
# 20                                     Siege of Darry  ...       False
# 21                               Battle of Duskendale  ...       False
# 22                       Battle of the Burning Septry  ...       False
# 23                            Battle of the Ruby Ford  ...       False
# 24                              Retaking of Harrenhal  ...       False
# 25                                    The Red Wedding  ...       False
# 26                                   Siege of Seagard  ...       False
# 27                             Battle of Castle Black  ...        True
# 28                                Fall of Moat Cailin  ...       False
# 29                                   Sack of Saltpans  ...       False
# 30                         Retaking of Deepwood Motte  ...        True
# 31                       Battle of the Shield Islands  ...       False
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...  ...       False
# 33                        Second Seige of Storm's End  ...       False
# 34                               Siege of Dragonstone  ...       False
# 35                                  Siege of Riverrun  ...       False
# 36                                 Siege of Raventree  ...       False
# 37                                Siege of Winterfell  ...       False
#
# [38 rows x 28 columns]

# %%
df_predict.loc[(df_predict.attacker_size == 0) & (df_predict.defender_size == 0), 'prediccion'] = 'NaN'
df_predict
# Out:
#                                                  name  ...  prediccion
# 0                          Battle of the Golden Tooth  ...        True
# 1                         Battle at the Mummer's Ford  ...       False
# 2                                  Battle of Riverrun  ...        True
# 3                            Battle of the Green Fork  ...       False
# 4                       Battle of the Whispering Wood  ...       False
# 5                                 Battle of the Camps  ...       False
# 6                                       Sack of Darry  ...       False
# 7                               Battle of Moat Cailin  ...       False
# 8                            Battle of Deepwood Motte  ...       False
# 9                           Battle of the Stony Shore  ...       False
# 10                         Battle of Torrhen's Square  ...       False
# 11                               Battle of Winterfell  ...       False
# 12                           Sack of Torrhen's Square  ...       False
# 13                                 Sack of Winterfell  ...       False
# 14                                  Battle of Oxcross  ...       False
# 15                               Siege of Storm's End  ...       False
# 16                                Battle of the Fords  ...        True
# 17                                  Sack of Harrenhal  ...       False
# 18                                 Battle of the Crag  ...       False
# 19                           Battle of the Blackwater  ...        True
# 20                                     Siege of Darry  ...       False
# 21                               Battle of Duskendale  ...       False
# 22                       Battle of the Burning Septry  ...       False
# 23                            Battle of the Ruby Ford  ...       False
# 24                              Retaking of Harrenhal  ...       False
# 25                                    The Red Wedding  ...       False
# 26                                   Siege of Seagard  ...       False
# 27                             Battle of Castle Black  ...        True
# 28                                Fall of Moat Cailin  ...       False
# 29                                   Sack of Saltpans  ...       False
# 30                         Retaking of Deepwood Motte  ...        True
# 31                       Battle of the Shield Islands  ...       False
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...  ...       False
# 33                        Second Seige of Storm's End  ...       False
# 34                               Siege of Dragonstone  ...       False
# 35                                  Siege of Riverrun  ...       False
# 36                                 Siege of Raventree  ...       False
# 37                                Siege of Winterfell  ...       False
#
# [38 rows x 28 columns]

# %%
lambda <arguments> : <Return Value if condition is True> if <condition> else <Return Value if condition is False>

# %%
df_got.transform
