# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardocarreras/Bootcamp_DataScience_student/blob/master/acortotesla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd   # Tratamiento dataframes
import numpy as np # Mates
import matplotlib.pyplot as plt #Gráficas
import seaborn as sns #Gráficas aún más chulas
import scipy # Estadísticas, ciencia
import os

nombre_fichero = "/content/accionesacortotesla.csv"

acorto=pd.read_csv(nombre_fichero, sep=",")


acorto.shape
# Out:
# (1059, 7)

# %%
acorto.head(11)
# Out:
#    Trade Facility        Date Symbol  Short Volume  Short Exempt Volume  \
# 0           NYTRF  2022-03-24   TSLA       1667483                 2440
# 1           NQTRF  2022-03-24   TSLA       4586143                29574
# 2           NCTRF  2022-03-24   TSLA        179234                    0
# 3           NCTRF  2022-03-23   TSLA        286107                    0
# 4           NYTRF  2022-03-23   TSLA       2982070                 6370
# 5           NQTRF  2022-03-23   TSLA       8269404                81950
# 6           NQTRF  2022-03-22   TSLA       7404320                48900
# 7           NYTRF  2022-03-22   TSLA       2432225                 2585
# 8           NCTRF  2022-03-22   TSLA        264573                    0
# 9           NQTRF  2022-03-21   TSLA       5240540                52303
# 10          NYTRF  2022-03-21   TSLA       2019055                 7415
#
#     Total Volume Market
# 0        2888078      N
# 1        7698267      Q
# 2         295311      B
# ...

# %%
acorto["porcentaje"]=acorto["Short Volume"]/acorto["Total Volume"]

# %%
acorto.head(11)
# Out:
#    Trade Facility        Date Symbol  Short Volume  Short Exempt Volume  \
# 0           NYTRF  2022-03-24   TSLA       1667483                 2440
# 1           NQTRF  2022-03-24   TSLA       4586143                29574
# 2           NCTRF  2022-03-24   TSLA        179234                    0
# 3           NCTRF  2022-03-23   TSLA        286107                    0
# 4           NYTRF  2022-03-23   TSLA       2982070                 6370
# 5           NQTRF  2022-03-23   TSLA       8269404                81950
# 6           NQTRF  2022-03-22   TSLA       7404320                48900
# 7           NYTRF  2022-03-22   TSLA       2432225                 2585
# 8           NCTRF  2022-03-22   TSLA        264573                    0
# 9           NQTRF  2022-03-21   TSLA       5240540                52303
# 10          NYTRF  2022-03-21   TSLA       2019055                 7415
#
#     Total Volume Market  porcentaje
# 0        2888078      N    0.577368
# ...

# %%
filtro = acorto["Market"] =="N"
solon = acorto[filtro]

# %%
solon.shape
# Out:
# (353, 8)

# %%
solon.head()
# Out:
#    Trade Facility        Date Symbol  Short Volume  Short Exempt Volume  \
# 0           NYTRF  2022-03-24   TSLA       1667483                 2440
# 4           NYTRF  2022-03-23   TSLA       2982070                 6370
# 7           NYTRF  2022-03-22   TSLA       2432225                 2585
# 10          NYTRF  2022-03-21   TSLA       2019055                 7415
# 13          NYTRF  2022-03-18   TSLA       1809549                 1638
#
#     Total Volume Market  porcentaje
# 0        2888078      N    0.577368
# 4        5142524      N    0.579885
# 7        4215153      N    0.577019
# 10       3357740      N    0.601314
# 13       3013544      N    0.600472

# %%
solon.shape
# Out:
# (353, 8)

# %%
solon["porcentaje"].hist()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-23ae64bfd2b8> in <module>()
# ----> 1 solon.head()
#
# AttributeError: 'Int64Index' object has no attribute 'head'

# %%
acorto.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fac75457f90>,
# ...
#       dtype=object)

# %%
pelis["movieId"]=pd.to_numeric(pelis["movieId"])

# %%
nombre_fichero2 = "/content/Clasificacion-220318-180251 (1).csv"

clasi=pd.read_csv(nombre_fichero2)

clasi.head()

clasi.shape
# Out:
# (100836, 4)

# %%
clasi.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp      int64
# dtype: object

# %%
datosjuntos=pd.merge(pelis, clasi)

datosjuntos.shape
# Out:
# (100836, 6)

# %%
datosjuntos2=datosjuntos.pivot_table(index=["userId"], columns=["title"], values="rating")

datosjuntos2.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# ...

# %%
clasificacion_toystory=datosjuntos2["Toy Story (1995)"]

# %%
datosjuntos2["Toy Story (1995)"]
# Out:
# userId
# 1      4.0
# 2      NaN
# 3      NaN
# 4      NaN
# 5      4.0
#       ...
# 606    2.5
# 607    4.0
# 608    2.5
# 609    3.0
# 610    5.0
# Name: Toy Story (1995), Length: 610, dtype: float64

# %%
similarpeliculas=datosjuntos2.corrwith(clasificacion_toystory)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
similarpeliculas.head()
# Out:
# title
# '71 (2014)                                NaN
# 'Hellboy': The Seeds of Creation (2004)   NaN
# 'Round Midnight (1986)                    NaN
# 'Salem's Lot (2004)                       NaN
# 'Til There Was You (1997)                 NaN
# dtype: float64

# %%
corr_similarpeliculas=pd.DataFrame(similarpeliculas, columns=["Correlaciones"])

corr_similarpeliculas=corr_similarpeliculas.dropna()

corr_similarpeliculas.sort_values("Correlaciones", ascending=False)

corr_similarpeliculas_=corr_similarpeliculas.sort_values("Correlaciones", ascending=False).reset_index()

corr_similarpeliculas_
# Out:
#                                                   title  Correlaciones
# 0     Land Before Time III: The Time of the Great Gi...            1.0
# 1                   Faster Pussycat! Kill! Kill! (1965)            1.0
# 2                                          Amen. (2002)            1.0
# 3        Machine Girl, The (Kataude mashin gâru) (2008)            1.0
# 4                                    Waydowntown (2000)            1.0
# ...                                                 ...            ...
# 4762                               In a World... (2013)           -1.0
# 4763                                    The Drop (2014)           -1.0
# 4764                                   Mo' Money (1992)           -1.0
# 4765                        Truly, Madly, Deeply (1991)           -1.0
# 4766                      I Was a Male War Bride (1949)           -1.0
#
# [4767 rows x 2 columns]

# %%
listaa=datosjuntos.genres.unique()
lista=[]
for i in range(len(listaa)):
    lista=lista+listaa[i].split("|")

# %%
lista=list(set(lista))

for i in lista:
    datosjuntos[i]=datosjuntos.genres.str.contains(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.

# %%
datosjuntos.tail()
# Out:
#         movieId                                      title  \
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                  genres  userId  rating   timestamp  \
# 100831  Action|Animation|Comedy|Fantasy     184     4.0  1537109082
# 100832         Animation|Comedy|Fantasy     184     3.5  1537109545
# 100833                            Drama     184     3.5  1537109805
# 100834                 Action|Animation     184     3.5  1537110021
# 100835                           Comedy     331     4.0  1537157606
#
#         (no genres listed)  Mystery  Horror  Animation  ...  Fantasy  \
# 100831               False    False   False       True  ...     True
# ...

# %%
datosjuntos_aux=datosjuntos.drop_duplicates(subset="title")

datosjuntos_aux.head()
# Out:
#      movieId                               title  \
# 0          1                    Toy Story (1995)
# 215        2                      Jumanji (1995)
# 325        3             Grumpier Old Men (1995)
# 377        4            Waiting to Exhale (1995)
# 384        5  Father of the Bride Part II (1995)
#
#                                           genres  userId  rating  timestamp  \
# 0    Adventure|Animation|Children|Comedy|Fantasy       1     4.0  964982703
# 215                   Adventure|Children|Fantasy       6     4.0  845553522
# 325                               Comedy|Romance       1     4.0  964981247
# 377                         Comedy|Drama|Romance       6     3.0  845554349
# 384                                       Comedy       6     5.0  845553938
#
#      (no genres listed)  Mystery  Horror  Animation  ...  Fantasy  Children  \
# 0                 False    False   False       True  ...     True      True
# ...

# %%
df=corr_similarpeliculas_.merge(datosjuntos_aux, how="left")
df=df.drop(columns=["movieId", "genres", "userId", "rating", "timestamp"])

df.head()
# Out:
#                                                title  Correlaciones  \
# 0  Land Before Time III: The Time of the Great Gi...            1.0
# 1                Faster Pussycat! Kill! Kill! (1965)            1.0
# 2                                       Amen. (2002)            1.0
# 3     Machine Girl, The (Kataude mashin gâru) (2008)            1.0
# 4                                 Waydowntown (2000)            1.0
#
#    (no genres listed)  Mystery  Horror  Animation  Comedy  Western   IMAX  \
# 0               False    False   False       True   False    False  False
# 1               False    False   False      False   False    False  False
# 2               False    False   False      False   False    False  False
# 3               False    False    True      False    True    False  False
# 4               False    False   False      False    True    False  False
#
#    Crime  ...  Fantasy  Children  Adventure  Musical  Documentary  Sci-Fi  \
# ...
